# %%
#generate latitude and longtitude
import pandas as pd
import googlemaps
Data = pd.read_csv("Data.csv")
gmaps_key = googlemaps.Client(key = 'AIzaSyDrMt8ozUAbp594j5BaZm_1tRnPMUR8Dhk')
Data['lat']=None
Data['lng']=None

for i in range(0,len(Data),1):
    geocode_result = gmaps_key.geocode(Data.iat[i,0])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lng = geocode_result[0]["geometry"]["location"]["lng"]
        Data.iat[i,Data.columns.get_loc("lat")] = lat
        Data.iat[i,Data.columns.get_loc("lng")] = lng
    except:
        lat = None
        lng = None

Data.to_csv('Data.csv',index=False)

# %%
Data
# Out:
#                                         Property_name  \
# 0             Apartment for rent Taman Kampar Perdana
# 1   Taman Kampar Perdana shop in front of Tesco Ka...
# 2             Tanah untuk disewa. 1ekar lebih. kampar
# 3                                  Meadow Park Kampar
# 4         Champs Elysees condo, bandar Agacia, Kampar
# 5   Renovated Single Storey Intermediate House At ...
# 6                                Kampar Flat For Rent
# 7        Rumah untuk Disewa di Kampar, Mamband Diawan
# 8             Rooms For Rent (The Meadow Park Kampar)
# 9      First Floor Big End Shop beside Tesco , Kampar
# 10  First Floor Office, Kampar, Tin Village, Next ...
# 11  Condo champs elysees kampar corner lot and nic...
# 12      Hot Condo for rent in West City Kampus Kampar
# 13                          Taman Cahaya Kampar Perak
# 14                    Room for Rent near UTHAR KAMPAR
# 15    NEW Fully Furnish Kampar Studio, Champs Elysees
# 16                                   Kampar new house
# 17                   Meadow Park Kampar room for rent
# 18  Studio Apartment for Rent Bandar Agacia UTAR T...
# 19  Single Storey Fully Furnished Lot House At Kampar
# 20            Condo unit for rent at Kampar west city
# 21    Kampar West City Condo - Fully Furnished - RENT
# 22  Rooms/House For Rent (Kampar Westlake Manchester)
# 23                 Kampar Putra Single Storey End Lot
# 24                                   Kampar Residence
# 25                         Apartment near UTAR Kampar
# 26                   Kampar Agriculture land for RENT
# 27                Kampar Champs Elysees room for rent
# 28  Kampar New Landed House Fully Funish 4 Rooms W...
# 29         Brand new unit | utar kampar | meadow park
# 30           Hot oxford room for rent westlake kampar
# 31          Hot harvard unit for rent westlake kampar
# 32              Champs Elysees Premium Studio, Kampar
# 33            Unit 2247 at Westlake - Harvard, Kampar
# 34                  Champs Elysees, Kampar (For Rent)
# 35                          Meadow Park Kampar, Perak
# 36                                   Kampar ipoh town
# 37  Fully Furnished Double Room With Air Cond At B...
# 38                                     Shoplot kampar
# 39                                     Bulatan kampar
# 40                                 Meadow Park Kampar
# 41  2021 Harvard, Jalan/Seksyen 2/2, Bandar Barat,...
# 42              Double storey HAVARD West Lake Kampar
# 43                   Kampar House(Near UTAR) for Rent
# 44  FullyFurnish New Champs Elysees 430sf Studio K...
# 45  UTAR Kampar West Lake Imperial Student House (...
# 46                        Kampar Putra house for rent
# 47  Single storey Jalan Putra Emas Kampar Putra Perak
# 48                            Room MH unilodge KAMPAR
#
#                  Renting_price             Area         Category  \
# 0         RM 450  per month          Kampar         Apartments
# 1       RM 1 500  per month          Kampar         Commercial
# 2       RM 1 000  per month          Kampar               Land
# 3         RM 300  per month          Kampar         Apartments
# 4         RM 700  per month          Kampar         Apartments
# 5         RM 800  per month          Kampar             Houses
# 6         RM 400  per month          Kampar         Apartments
# 7         RM 450  per month          Kampar             Houses
# 8         RM 320  per month          Kampar              Rooms
# 9         RM 590  per month          Kampar         Commercial
# 10      RM 1 000  per month          Kampar         Commercial
# 11        RM 700  per month          Kampar         Apartments
# 12        RM 800  per month          Kampar         Apartments
# 13        RM 500  per month          Kampar             Houses
# 14        RM 200  per month          Kampar              Rooms
# 15        RM 650  per month          Kampar         Apartments
# 16        RM 550  per month          Kampar             Houses
# 17        RM 300  per month          Kampar              Rooms
# 18        RM 600  per month          Kampar         Apartments
# 19      RM 1 300  per month          Kampar             Houses
# 20        RM 700  per month          Kampar         Apartments
# 21        RM 780  per month          Kampar         Apartments
# 22        RM 230  per month          Kampar              Rooms
# 23        RM 600  per month          Kampar             Houses
# 24      RM 1 000  per month          Kampar         Apartments
# 25        RM 400  per month          Kampar         Apartments
# 26      RM 1 000  per month          Kampar               Land
# 27        RM 650  per month          Kampar              Rooms
# 28      RM 1 100  per month          Kampar             Houses
# 29        RM 330  per month          Kampar              Rooms
# 30        RM 270  per month          Kampar              Rooms
# 31      RM 1 100  per month          Kampar             Houses
# 32        RM 650  per month          Kampar              Rooms
# 33        RM 240  per month          Kampar              Rooms
# 34        RM 650  per month          Kampar         Apartments
# 35        RM 300  per month          Kampar              Rooms
# 36      RM 2 000  per month          Kampar         Commercial
# 37        RM 500  per month          Kampar              Rooms
# 38        RM 700  per month          Kampar         Commercial
# 39        RM 800  per month          Kampar         Commercial
# 40        RM 300  per month          Kampar              Rooms
# 41        RM 340  per month          Kampar              Rooms
# 42        RM 850  per month          Kampar             Houses
# 43        RM 300  per month          Kampar              Rooms
# 44        RM 650  per month          Kampar         Apartments
# 45        RM 220  per month          Kampar              Rooms
# 46        RM 650  per month          Kampar             Houses
# 47        RM 700  per month          Kampar             Houses
# 48        RM 300  per month          Kampar              Rooms
#
#              Size          Bedroom          Bathroom  \
# 0      915 sq.ft      3 Bedrooms       2 Bathrooms
# 1     1760 sq.ft              None              None
# 2        1 Acres              None              None
# 3      200 sq.ft       1 Bedroom        1 Bathroom
# 4      430 sq.ft       1 Bedroom        1 Bathroom
# 9    The Shop is located very close to East Gate U...  4.33536  101.154
# 10   ++++ Kampar Office for rent ++++Details:-- Of...  4.32807  101.147
# 11   Hi,,i want to rent out my unit at champs elys...  4.32276  101.125
# 12                                    5 mins to UTAR   4.32382   101.13
# 13   Teres Setingkat3 Bilik 2 Bilik AirEndlot Berd...  4.28691  101.141
# 14   => Double storey terrance house=> Near Tesco ...  4.32717  101.136
# 15   NEW Fully Furnish Studio Room For RentFully f...  4.32276  101.125
# 16   Jalan Putra Berlian, Taman Kampar Putra, Kamp...  4.32891  101.135
# 17   Guarded town house with a car park fully furn...  4.31454  101.125
# 18   This luxurious service apartment is perfect f...   4.3206  101.124
# 19   First come first serve!!!!Single Storey Fully...   4.3085  101.154
# 20   Location- located at Kampus West Condo- situa...  4.32436  101.126
# 21   This property is strategically located within...  4.32382   101.13
# 22   Kampar Westlake Manchester- Newly painted roo...  4.32891  101.135
# 23   Single Storey walking distance to Bus Termina...  4.32276  101.126
# 24   Location  near UTAR/ KTAR/Westlake Internatio...  4.32894  101.151
# 25   Fully furnished NEW apartment available for r...  4.33013  101.145
# 26   Kampar LandAgriculture land to letRental Rm10...   4.3085  101.154
# 27   -Fully furnished with air-conditioned, cookin...   4.3286  101.126
# 28   Kampar New Landed House Almost Fully Furnish ...  4.34007  101.143
# 29   BEST PLACE TO STAY IN KAMPAR *A Modern Adobe ...  4.31454  101.125
# 30   FULLY FURNISHEDWITH OR WITHOUT AIR CONNEARBY ...   51.752 -1.25773
# 31   FULLY FURNISHEDNEARBY UTAR WITHIN 8 MINSNEARB...   4.3085  101.154
# 32   *****2 UNITS OF SERVICED SUIT FOR RENT*****- ...  4.32276  101.125
# 33   2247, Double Storey Terrace House for RentLoc...     None     None
# 34   The apartment is composed of a living room, a...  4.32276  101.125
# 35   online payment transfer/cash. room available ...  4.31454  101.125
# 36    kampar 3unit shop lot for rent call 0162224413   4.58322  101.088
# 37   Double room with air cond available from Janu...  4.32403  101.151
# 38   Shop lot tingkat satu (atas) utk di sewa, kel...  4.31283  101.153
# 39         First floor of Taman Tiara shop lot No. 6    4.3085  101.154
# 40   Guarded town house with a car park fully furn...  4.31454  101.125
# 41   Well-kept double-storey corner lot with extra...  4.32936  101.132
# 42   Fully furnished double storey house next to U...  4.33213   101.14
# 43   Newly completed townhouse which is gated and ...  4.32717  101.136
# 44   GS Realty Sdn BhdJamie Leong 012 253 2618====...   4.3286  101.126
# 45   UTAR Kampar West Lake Imperial Student House-...  4.32891  101.135
# 46   Single storey house in Kampar Putra, Kampar f...  4.32717  101.136
# 47   Single storey Jalan Putra Emas  Kampar Putra ...  4.32081  101.133
# 48   • Fully Furnished• Water Filter / Water Dispe...   4.3297  101.155
