# %%
import pandas as pd
df = pd.read_csv('./scrapper/survData_03032020.csv')

# %%
df['Property_name']=df['Property_name'].str.strip()
spt = df.groupby(df['Property_name'].str.lower())
spt.first()
# Out:
#                        Property_name  Renting_price   Category  Size  Bedroom  \
# Property_name
# beijing                      Beijing            315       Room     0        1
# cambridge                  Cambridge            240       Room     0        1
# champs                        Champs            560       Room     0        1
# eastlake                    Eastlake            450      House     0        3
# harvard                      Harvard            240       Room     0        1
# imperial                    Imperial           3450      House     0       11
# kampar putra            Kampar Putra            900       Room     0        1
# mahsuri                      Mahsuri            310       Room     0        1
# manchester                Manchester            270       Room     0        1
# meadow park              Meadow Park           1150  Apartment     0        4
# oxford                        Oxford            170       Room     0        1
# ...

# %%
house
# Out:
#        Property_name  Renting_price Category  Size  Bedroom  Bathroom  \
# 11          Imperial           3450    House   0.0       11        11
# 15         West city            700    House   0.0        3         2
# 18  Trails of kampar           1000    House   0.0        3         2
# 27         Cambridge           3350    House   0.0       14        12
# 29           Harvard            900    House   0.0        4         4
# 31          Westcity            225    House   0.0        3         2
# 32           Harvard            900    House   0.0        4         4
# 36           Beijing           3350    House   0.0       12        12
# 44            trails           1200    House   0.0        3         2
# 47           Harvard            900    House   0.0        4         4
# 53           Harvard            280    House   0.0        1         1
# 54           Harvard           1150    House   0.0        4         3
# ...
